# %% [markdown]
# # Document (QnA) Matching Data Science Process
#
# ## Part 2: TF-IDF and Cosine Similarity - Match Q to Similar A
#
# ### Overview
#
# __Part 2__ of the series shows the process of matching Questions to Answers based on the _Cosine Similarity_ of their _Term Frequency-Inverse Document Frequency (TF-IDF)_ matrix.
#
# <img src="https://raw.githubusercontent.com/Azure/Document_Matching/master/pic/experiment1_overview.PNG?token=APoO9gLiCcPVowvW0OsAuuXD9coI-HEsks5Ynhp0wA%3D%3D">
#
# Note: This notebook series are built under Python 3.5 and NLTK 3.2.2.

# %% [markdown]
# ## Import required Python modules

# %%
import pandas as pd
import math
import numpy as np
from numpy import linalg as LA
from azure.storage import CloudStorageAccount
from IPython.display import display

# suppress all warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Read trainQ and testQ into DataFrames

# %%
trainQ_url = 'https://mezsa.blob.core.windows.net/stackoverflow/trainQwithTokens.tsv'
testQ_url = 'https://mezsa.blob.core.windows.net/stackoverflow/testQwithTokens.tsv'
answersC_url = 'https://mezsa.blob.core.windows.net/stackoverflow/answersCwithTokens.tsv'

trainQ = pd.read_csv(trainQ_url, sep='\t', index_col='Id', encoding='latin1')
testQ = pd.read_csv(testQ_url, sep='\t', index_col='Id', encoding='latin1')
answersC = pd.read_csv(answersC_url, sep='\t', index_col='Id', encoding='latin1')

# %% [markdown]
# ## Create Tokens to IDs Hash
#
# For each token in the entire vocabulary, we assign it an unique ID.

# %%
# get Token to ID mapping: {Token: tokenId}
def tokens_to_ids(tokens, featureHash):
    token2IdHash = {}
    for i in range(len(tokens)):
        tokenList = tokens.iloc[i].split(',')
        if featureHash is None:
            for t in tokenList:
                if t not in token2IdHash.keys():
                    token2IdHash[t] = len(token2IdHash)
        else:
            for t in tokenList:
                if t not in token2IdHash.keys() and t in list(featureHash.keys()):
                    token2IdHash[t] = len(token2IdHash)
            
    return token2IdHash

# %%
token2IdHashInit = tokens_to_ids(trainQ['Tokens'].append(answersC['Tokens']), None)

# %%
print("Total number of unique tokens in the TrainQ and Answers: " + str(len(token2IdHashInit)))
# Out:
# Total number of unique tokens in the TrainQ and Answers: 5266

# %% [markdown]
# ## Create Count Matrix for Each Token in Each Question/Answer

# %%
def count_matrix(frame, token2IdHash, uniqueAnswerId):
    # create am empty matrix with the shape of:
    # num_row = num of unique tokens
    # num_column = num of unique answerIds (N_wA) or num of questions
    # rowIdx = token2IdHash.values()
    # colIdx = index of uniqueAnswerId (N_wA) or index of questions
    num_row = len(token2IdHash)
    if uniqueAnswerId is not None:  # get N_wA
        num_column = len(uniqueAnswerId)
    else:
        num_column = len(frame)
    countMatrix = np.empty(shape=(num_row, num_column))

    # loop through each question in the frame to fill in the countMatrix with corresponding counts
    for i in range(len(frame)):
        tokens = frame['Tokens'].iloc[i].split(',')
        if uniqueAnswerId is not None:   # get N_wA
            answerId = frame['AnswerId'].iloc[i]
            colIdx = uniqueAnswerId.index(answerId)
        else:  
            colIdx = i
            
        for t in tokens:
            if t in token2IdHash.keys():
                rowIdx = token2IdHash[t]
                countMatrix[rowIdx, colIdx] += 1

    return countMatrix

# %%
# calculate the count matrix of all training questions and answers.
N_wQA = count_matrix(trainQ.append(answersC), token2IdHashInit, uniqueAnswerId=None)

# %% [markdown]
# ## Compute IDF Vector
#
# Considering all tokens observed in the training questions and answers, we compute their Inverse Document Frequency based on the below formula.
#
# <img src="https://raw.githubusercontent.com/Azure/Document_Matching/master/pic/idf.PNG?token=APoO9qf3WptQgUPVRQJuOt4cobf56-Y3ks5YnhLSwA%3D%3D">

# %%
def get_idf(N_wQA):
    # N is total number of documents in the corpus
    # N_V is the number of tokens in the vocabulary
    N_V, N = N_wQA.shape
    # D is the number of documents where the token w appears
    D = np.empty(shape=(0, N_V))
    for i in range(N_V):
        D = np.append(D, len(np.nonzero(N_wQA[i, ])[0]))
    return np.log(N/D)

# %%
idf = get_idf(N_wQA)

# %% [markdown]
# ## Calculate Normalized TF of Each Word w in Test and Answers Sets
#
# Each document d is typically represented by a feature vector x that represents the contents of d. Because different documents can have different lengths, it can be useful to apply L1 normalmalized feature vector x. Therefore, a normalized Term Frequency matrix can be obtained based on the below formula.
#
# <img src="https://raw.githubusercontent.com/Azure/Document_Matching/master/pic/tf.PNG?token=APoO9tMyEVzqoUJYT9ALcdF3_BryHHEVks5YnIQywA%3D%3D">

# %%
def normalize_tf(frame, token2IdHash):
    N_w = count_matrix(frame, token2IdHash, uniqueAnswerId=None)
    # get the column sum of the count matrix
    N_W = np.sum(N_w, axis=0)
    
    # find the index where N_WQ is zero
    zeroIdx = np.where(N_W == 0)[0]
    
    # if N_W is zero, then the x_w for that particular question/answer would be zero.
    # for a simple calculation, we convert the N_WQ to 1 in those cases so the demoninator is not zero. 
    if len(zeroIdx) > 0:
        N_W[zeroIdx] = 1
    
    # x_w = P_wd = count(w)/sum(count(i in V))
    x_w = N_w / N_W
    
    return x_w

# %%
# calculate tf matrix of test question and answers independently.
x_wTest = normalize_tf(testQ, token2IdHashInit)
x_wAns = normalize_tf(answersC, token2IdHashInit)

# %% [markdown]
# ## Compute TF-IDF Matrix
#
# By knowing the Term Frequency (TF) matrix and Inverse Document Frequency (IDF) vector, we can simply compute TF-IDF matrix by multiplying them together.
#
# <img src="https://raw.githubusercontent.com/Azure/Document_Matching/master/pic/tfidf.PNG?token=APoO9gw3rPhLusbG3if65TuVZNAnyqTCks5YnhWPwA%3D%3D">

# %%
tfidfTest = (x_wTest.T * idf).T
tfidfAns = (x_wAns.T * idf).T

# %% [markdown]
# ## Calculate Cosine Similarity between Test Set and Answers
#
# For each question in the Test set, we compute its Consine Similarity against all answers in the Answers set. This similarity is a score that we use to consider how similar a question and an answer is.
#
# <img src="https://raw.githubusercontent.com/Azure/Document_Matching/master/pic/cosine.PNG?token=APoO9lOcKkP_7tFDh7p6KZXXVmokwLbGks5YnhY-wA%3D%3D">

# %%
def consine_similarity(tfidfL, tfidfR):
    # calculate the dot product of two tfidf arrays
    N = np.dot(tfidfL.T, tfidfR)
    # calculate the norm of each tfidf array
    normL = LA.norm(tfidfL, axis = 0)
    normR = LA.norm(tfidfR, axis = 0)
    similarity = (N.T/normL).T/normR
    
    return similarity

# %%
# calculate similarity scores of each question in Test set against all answers. 
simScores = consine_similarity(tfidfTest, tfidfAns)

# %% [markdown]
# ## Rank the Cosine Similarity and Calcualte Average Rank
#
# We use two evaluation matrices to test our model performance. For each question in the test set, we calculate a Cosine Similarity score against each answer. Then we rank the answers based on their Cosine Similarity scores to calculate Average Rank and Top 10 Percentage in the Test set using the below formula:
#
# <img src="https://raw.githubusercontent.com/Azure/Document_Matching/master/pic/evaluation.PNG?token=APoO9hyYDFxGc9FRbmIXU3VGv0wdeCaPks5YnIVtwA%3D%3D">

# %%
# sort the similarity scores in descending order and map them to the corresponding AnswerId in Answer set
def rank(frame, scores, uniqueAnswerId):
    frame['SortedAnswers'] = list(np.array(uniqueAnswerId)[np.argsort(-scores, axis=1)])
    
    rankList = []
    for i in range(len(frame)):
        rankList.append(np.where(frame['SortedAnswers'].iloc[i] == frame['AnswerId'].iloc[i])[0][0] + 1)
    frame['Rank'] = rankList
    
    return frame

# %%
# get unique answerId in ascending order.
uniqueAnswerId = answersC.index.values
# calculate the rank of each question in Test set.
testQ = rank(testQ, simScores, uniqueAnswerId)

# %%
# average of rank
print('Average of rank: ' + str(np.floor(testQ['Rank'].mean())))
print('Total number of questions in test set: ' + str(len(testQ)))
print('Total number of answers: ' + str(len(uniqueAnswerId)))
print('Total number of unique features: ' + str(len(token2IdHashInit)))
print('Percentage of questions find answers in top 10: ' + str(round(len(testQ.query('Rank <= 10'))/len(testQ), 3)))
# Out:
# Average of rank: 257.0
# Total number of questions in test set: 3671
# Total number of answers: 1275
# Total number of unique features: 5266
# Percentage of questions find answers in top 10: 0.199

# %%
testQ.query('Rank <= 3')
# Out:
#             AnswerId                                              Text0  \
# Id
# 15762825      3777.0  Call a c# function from JavaScript in asp.net....
# 32363998     27943.0  Function to calculate geospatial distance betw...
# 21757141     41960.0  Date substract in javascript. <p>How do I subt...
# 14004216     52597.0  Placeholder while an image is loading with Emb...
# 21849065     63506.0  How to take screenshot of remote website by ur...
# 27087687    105074.0  Generate unique product id. <p>I have a page t...
# 34564112    109091.0  jQuery break setInterval operation. <p>i try t...
# 34825965    109091.0  run an ajax call while waiting for the first t...
# 33176982    111111.0  Nodejs closures and res object in a callback f...
# 33981274    111111.0  Understanding Closures. <p>I was going through...
# 28052244    118251.0  How many monospace characters fit horizontally...
# 28756444    119473.0  Highlight search word by adding span?. <p>Curr...
# 30894752    162579.0  HTML vs. JavaScript form validation. <p>I am n...
# 31703350    175787.0  check a string variable for string and Integer...
# 27805737    196687.0  Get text value of selected option in Jquery. <...
# 23175528    198031.0  Javascript: How to use eval() safely. <p>I am ...
# 28819503    198031.0  When and how is javascript eval() vulnerable t...
# 26647511    220233.0  Is there a JS API to get information about hea...
# 35604233    220233.0  How to read http request headers with javascri...
# 29593265    221297.0  Get timestamp of current hour in Javascript. <...
# 20786248    276739.0  how can i change language of onbeforeunload me...
# 28374830    276739.0  How to hide the original confirm in JavaScript...
# 22046535    287173.0  Javascript regex to replace special characters...
# 27402698    322827.0  How to check whether the mouse left button is ...
# 31216296    336868.0  Why javascript function can be invoked before ...
# 33722178    336868.0  What is difference in this javacascript functi...
# 35448558    336868.0  is there any difference in the 2 main ways to ...
# 31048551    359509.0  Proper javascript coding guidelines regarding ...
# 31658864    359509.0  How does Javascript equality operator works?. ...
# 23809676    362564.0  How to change Iframe height based on its conte...
# ...              ...                                                ...
# 28921908  22621547.0  Python/Flask and Javascript: How can I pass a ...
# 33273799  23392650.0  Why does Chrome console.log show my variable u...
# 28261942  23740549.0  Best way to return multiple values in echo fro...
# 33855394  23740549.0  How do I load MySQL data using PHP into a Java...
# 33041382  23945027.0  How can I extract certain content from a strin...
# 31115833  24070373.0  JQuery Script link placement in HTML. <p>I am ...
# 35612428  24193596.0  Call async/await functions in parallel. <p>As ...
# 26389414  24226769.0  Meteor blaze select a specific item by the arr...
# 35273981  24226769.0  How to know the iteration number in Meteor. <p...
# 21895940  24359746.0  Why doesn't my page-mod contentStyle font-face...
# 30955455  25111942.0  ng:areq error in simple app. <p>I have this ve...
# 31832614  25111942.0  AngularJS Plnkr Problems. <p>Ironically I have...
# 16642919  25328170.0  Disable all div contents using jquery includin...
# 32682848  25785794.0  Certain AngularJS functions not working when a...
# 30194775  25881231.0  Funny behavior of Underscore template. <p>I tr...
# 32922049  25881231.0  Backbone can't see a key passed to the templat...
# 32965066  25881231.0  How to render model attributes in underscore t...
# 31011661  27096404.0  Set Comparability for Objects in ECMA6 JS. <p>...
# 32768045  27149227.0  How do I make this. work with promises and gen...
# 34386035  28692824.0  Difference between promise and deferred when w...
# 35317585  28728380.0  Angular Js ng-controller is not populating the...
# 35540513  28728380.0  data-binding in Angular 1.0.1 and 1.5. <p>I'm ...
# 35052698  29182787.0  How to apply ES6 template to string variable. ...
# 35345374  29182787.0  How to interpret file content as template stri...
# 35706164  29598404.0  Typescript import/as vs import/require?. <p>I ...
# 35261608  29621542.0  Javascript destructuring to populate existing ...
# 34530250  29924193.0  NodeJS debug module with ES2015. <p>I am migra...
# 34939074  29924193.0  common js require vs. ES2015 import. <p>In a l...
# 33730291  31086018.0  Greasemonkey swallows JS errors without loggin...
# 35496925  32223950.0  Settimeout in animation. <p>How to implement t...
#
#                      CreationDate  \
# Id
# 15762825  2013-04-02 11:21:29.383
# 32363998  2015-09-02 22:11:35.147
# 21757141  2014-02-13 14:34:20.863
# 14004216  2012-12-22 15:56:10.010
# 21849065  2014-02-18 09:19:34.343
# 27087687  2014-11-23 09:57:12.213
# 34564112  2016-01-02 08:42:42.683
# 34825965  2016-01-16 10:37:30.117
# 33176982  2015-10-16 18:11:55.243
# 33981274  2015-11-29 09:28:26.687
# 28052244  2015-01-20 18:07:51.857
# 28756444  2015-02-27 02:19:18.150
# 30894752  2015-06-17 14:36:54.763
# 31703350  2015-07-29 14:25:38.023
# 27805737  2015-01-06 19:25:28.930
# 22046535  javascript regex to replace special characters...     255.0
# 27402698  how to check whether the mouse left button is ...     470.0
# 31216296  why javascript function can be invoked before ...     286.0
# 33722178  what is difference in this javacascript functi...     310.0
# 35448558  is there any difference in the 2 main ways to ...     300.0
# 31048551  proper javascript coding guidelines regarding ...     959.0
# 31658864  how does javascript equality operator works?. ...     338.0
# 23809676  how to change iframe height based on its conte...     473.0
# ...                                                     ...       ...
# 28921908  python/flask and javascript: how can i pass a ...     604.0
# 33273799  why does chrome console.log show my variable u...    1294.0
# 28261942  best way to return multiple values in echo fro...     768.0
# 33855394  how do i load mysql data using php into a java...     628.0
# 33041382  how can i extract certain content from a strin...     199.0
# 31115833  jquery script link placement in html. i am a l...     497.0
# 35612428  call async/await functions in parallel. as far...     507.0
# 26389414  meteor blaze select a specific item by the arr...     183.0
# 35273981  how to know the iteration number in meteor. i'...     500.0
# 21895940  why doesn't my page-mod contentstyle font-face...     898.0
# 30955455  ng:areq error in simple app. i have this very ...     272.0
# 31832614  angularjs plnkr problems. ironically i have be...     501.0
# 16642919  disable all div contents using jquery includin...     317.0
# 32682848  certain angularjs functions not working when a...    1372.0
# 30194775  funny behavior of underscore template. i try t...     601.0
# 32922049  backbone can't see a key passed to the templat...     289.0
# 32965066  how to render model attributes in underscore t...     878.0
# 31011661  set comparability for objects in ecma6 js. i'v...     643.0
# 32768045  how do i make this. work with promises and gen...     615.0
# 34386035  difference between promise and deferred when w...     353.0
# 35317585  angular js ng-controller is not populating the...     339.0
# 35540513  data-binding in angular 1.0.1 and 1.5. i'm won...     358.0
# 35052698  how to apply es6 template to string variable. ...     415.0
# 35345374  how to interpret file content as template stri...     308.0
# 35706164  typescript import/as vs import/require?. i am ...     545.0
# 35261608  javascript destructuring to populate existing ...     455.0
# 34530250  nodejs debug module with es2015. i am migratin...     393.0
# 34939074  common js require vs. es2015 import. in a lot ...     367.0
# 33730291  greasemonkey swallows js errors without loggin...     537.0
# 35496925  settimeout in animation. how to implement the ...     257.0
#
#                                             TextWithPhrases  \
# Id
# 15762825  call a c# function from javascript in asp.net ...
# 32363998  function to calculate geospatial distance betw...
# 21757141  date substract in javascript how do i subtract...
# 14004216  placeholder while an image is loading with emb...
# 21849065  how to take screenshot of remote website by ur...
# 27087687  generate unique product id i have a page that ...
# 34564112  jquery break setinterval operation i try to br...
# 34825965  run an ajax call while waiting for the first t...
# 33176982  nodejs closures and res object in a callback_f...
# 33981274  understanding closures i was going through an ...
# 28052244  how many monospace characters fit horizontally...
# 28756444  highlight search word by adding span currently...
# 30894752  html vs. javascript form validation i am new t...
# 31703350  check a string variable for string and integer...
# 27805737  get text value of selected option in jquery i ...
# 23175528  javascript how to use eval safely i am buildin...
# 28819503  when and how is javascript eval vulnerable to ...
# 26647511  is there a js api to get information about hea...
# 35604233  how to read http_request headers with javascri...
# 29593265  get timestamp of current hour in javascript is...
# 20786248  how can i change language of onbeforeunload me...
# 28374830  how to hide the original confirm in javascript...
# 22046535  javascript regex to replace special_characters...
# 27402698  how to check whether the mouse left button is ...
# 31216296  why javascript_function can be invoked before ...
# 33722178  what is difference in this javacascript functi...
# 35448558  is there any difference in the 2 main ways to ...
# 31048551  proper javascript coding guidelines regarding ...
# 31658864  how does javascript equality operator works i ...
# 23809676  how to change iframe height based on its conte...
# ...                                                     ...
# 28921908  python/flask and javascript how can i pass a s...
# 33273799  why does chrome console.log show my variable u...
# 28261942  best_way to return multiple values in echo fro...
# 33855394  how do i load mysql data using php into a java...
# 33041382  how can i extract certain content from a strin...
# 31115833  jquery script link placement in html i am a li...
# 35612428  call async/await functions in parallel as far ...
# 26389414  meteor blaze select a specific item by the arr...
# 35273981  how to know the iteration number in meteor i'm...
# 21895940  why doesn't my page-mod contentstyle font-face...
# 30955455  ng areq error in simple app i have this very s...
# 31832614  angularjs plnkr problems ironically i have bee...
# 16642919  disable all div contents using_jquery includin...
# 32682848  certain angularjs functions not working when a...
# 30194775  funny behavior of underscore template i try to...
# 32922049  backbone can't see a key passed to the templat...
# 32965066  how to render model attributes in underscore t...
# 31011661  set comparability for objects in ecma6 js i've...
# 32768045  how do i make this work with promises and gene...
# 34386035  difference between promise and deferred when w...
# 35317585  angular js ng-controller is not populating the...
# 35540513  data-binding in angular 1.0.1 and 1.5. i'm_won...
# 35052698  how to apply es6 template to string variable w...
# 35345374  how to interpret file content as template stri...
# 35706164  typescript import/as vs import/require i am us...
# 35261608  javascript destructuring to populate existing ...
# 34530250  nodejs debug module with es2015 i am migrating...
# 34939074  common js require vs. es2015 import in a lot o...
# 33730291  greasemonkey swallows js errors without loggin...
# 35496925  settimeout in animation how to implement the c...
#
#                                                      Tokens  \
# Id
# 15762825  c#,asp.net,named,inside,c#,want,need,operation...
# 32363998  calculate,distance,two,points,lat,long,using,p...
# 21757141  date,subtract,dates,string,date,subtract,date,...
# 14004216  placeholder,image,loading,possible_duplicate,s...
# 21849065  screenshot,remote,website,url,wondering,screen...
# 27087687  generate,unique,product,id,page,receive,site,a...
# 34564112  jquery,break,setinterval,operation,try,break,s...
# 34825965  run,ajax,waiting,first,complete,ajax,long,comp...
# 33176982  nodejs,closures,res,object,callback_function,w...
# 33981274  understanding,closures,advanced,text,came,code...
# 28052244  characters,fit,horizontally,vertically,element...
# 28756444  highlight,search,word,adding,span,currently,tr...
# 30894752  html,vs.,form,validation,new,end,web,developme...
# 31703350  check,string,variable,string,integer,following...
# 27805737  text,value,selected,option,jquery,custom,jquer...
# 23175528  eval,safely,building,little,game,point,need,ca...
# 28819503  eval,injection,new,team,member,looking,noticed...
# 26647511  js,api,information,headers,sent,course,set,hea...
# 35604233  read,http_request,headers,launches,webpage,wan...
# 29593265  timestamp,current,hour,possible,utc,time,curre...
# 20786248  change,language,onbeforeunload,message,typical...
# 28374830  hide,original,confirm,onbeforeunload,i'm,creat...
# 22046535  regex,replace,special_characters,replace,symbo...
# 27402698  check,mouse,left,button,mouse,situation,initia...
# 31216296  javascript_function,invoked,defined,block,work...
# 33722178  difference,definition,syntax,i'm,beginner,prog...
# 35448558  difference,main,ways,define,javascript_functio...
# 31048551  proper,coding,guidelines,regarding,comparisons...
# 31658864  equality,operator,works,trying,came,scenario,e...
# 23809676  change,iframe,height,based,content,iframe,cont...
# ...                                                     ...
# 28921908  pass,string,i'm_looking,simple,way,pass,string...
# 33273799  chrome,console.log,variable,updated,updated,di...
# 28261942  best_way,return,multiple,values,echo,php,parsi...
# 33855394  load,mysql,data,using,php,javascript_array,i'm...
# 33041382  extract,certain,content,string,certain,urls,ex...
# 31115833  jquery,script,link,placement,html,little,confu...
# 35612428  functions,parallel,far,understand,putting,mult...
# 26389414  meteor,select,specific,item,array,index,way,ac...
# 35273981  know,iteration,number,meteor,i'm_trying,meteor...
# 21895940  rule,firefox,addon,work,i'm_trying,inject,page...
# 30955455  ng,areq,error,simple,app,simple,angular,exampl...
# 31832614  angularjs,problems,trying,set,question,ask,sta...
# 16642919  disable,all,div,contents,using_jquery,includin...
# 32682848  certain,angularjs,functions,working,accessed,u...
# 30194775  funny,behavior,underscore,template,try,pass,da...
# 32922049  backbone,key,passed,template,simple,order,temp...
# 32965066  render,model,attributes,underscore,template,us...
# 31011661  set,objects,ecma6,js,using,set,store,retrieve,...
# 32768045  make,work,promises,generic,functions,trying,fo...
# 34386035  difference,promise,deferred,wrapping,entire,bl...
# 35317585  angular,js,ng-controller,populating,value,dupl...
# 35540513  angular,i'm_wondering,work,old,version,angular...
# 35052698  apply,es6,template,string,variable,es6,string,...
# 35345374  interpret,file,content,template,string,wonderi...
# 35706164  typescript,vs,using,typescript,modules,typescr...
# 35261608  destructuring,populate,existing,object,i'm_usi...
# 34530250  nodejs,debug,module,found,having,little,issue,...
# 34939074  common,js,require,vs.,import,lot,written,node....
# 33730291  greasemonkey,js,errors,logging,greasemonkey,sc...
# 35496925  settimeout,animation,implement,animation,anima...
#
#                                               SortedAnswers  Rank
# Id
# 15762825  [476445, 994406, 3777, 206932, 19391416, 74753...     3
# 32363998  [27943, 938195, 1726662, 4960020, 9316216, 134...     1
# 21757141  [41960, 1016908, 4365317, 1056730, 7556634, 32...     1
# 14004216  [52597, 934925, 1288555, 7225820, 6150397, 328...     1
# 21849065  [6678156, 63506, 20035319, 3059129, 3528331, 1...     2
# 27087687  [11114634, 105074, 2100767, 16120977, 6680842,...     2
# 34564112  [7421030, 109091, 11600783, 10313023, 10050496...     2
# 34825965  [4402359, 109091, 8563735, 10899796, 10050826,...     2
# 33176982  [111111, 11192941, 13418980, 1225683, 4841288,...     1
# 33981274  [3924998, 111111, 4091780, 3059129, 11192941, ...     2
# 28052244  [118251, 4230951, 6677069, 9337047, 8876069, 3...     1
# 28756444  [1789952, 150824, 119473, 4960020, 20533988, 9...     3
# 30894752  [469362, 162579, 1423783, 7562439, 16591845, 4...     2
# 31703350  [1789952, 154068, 175787, 2441379, 1433217, 62...     3
# 27805737  [196687, 496126, 16913242, 13049740, 1085810, ...     1
# 23175528  [9107367, 1197585, 198031, 599109, 1664294, 31...     3
